# %%
# !nvidia-smi
# Out:
# Sun Nov 17 16:56:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 49.6 MB/s eta 0:00:00
# ...

# %%
# !yolo task= detect mode= train model= yolov8n.pt data="/content/drive/MyDrive/Ai_pro/aag laga di aag/Fire_Detector_model/data/data.yaml" epochs= 15 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 431MB/s]
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image

f1_score_image_path = "/content/runs/detect/train/F1_curve.png"

Image(filename=f1_score_image_path)

# %%
from IPython.display import Image

f1_score_image_path = "/content/runs/detect/train/PR_curve.png"

Image(filename=f1_score_image_path)

# %%
from ultralytics import YOLO

# %%
from IPython.display import Image

conf_matrix_image_path = "/content/runs/detect/train/confusion_matrix.png"

Image(filename=conf_matrix_image_path)
